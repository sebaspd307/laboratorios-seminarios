# %% [markdown]
# #integrantes:
#
# - Edgar Sebastian peña diaz
# - leyder bolaños

# %% [markdown]
# ## importacion de librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## creacion de objetos

# %%
# Definimos un diccionario llamado 'data' que contiene información sobre los años, equipos,
# y sus respectivos resultados (victorias, empates y derrotas)
data = { 'year':[2010,2011,2012,2010,2011,2012,2010,2011,2012],
        'team':['FCBarcelona', 'FCBarcelona','FCBarcelona', 'RMadrid','RMadrid', 'RMadrid','ValenciaCF', 'ValenciaCF','ValenciaCF'],
         'wins':[30, 28, 32, 29, 32, 26, 21, 17, 19],
         'draws': [6, 7, 4, 5, 4, 7, 8, 10, 8],
         'losses': [2, 3, 2, 4, 2, 5, 9, 11, 11]
         }
# Creamos un DataFrame de pandas llamado 'football' a partir del diccionario 'data'
# Especificamos el orden de las columnas para el DataFrame
football = pd.DataFrame(data , columns = [
'year', 'team', 'wins', 'draws', 'losses'
]
)

# %% [markdown]
# ##Carga del documento y uso de la libreria panda

# %%
edu = pd.read_csv('/content/educ_figdp_1_Data.csv',

na_values = ':',
usecols = ["TIME","GEO","Value"])

edu
# Out:
#      TIME                            GEO  Value
# 0    2000  European Union (28 countries)    NaN
# 1    2001  European Union (28 countries)    NaN
# 2    2002  European Union (28 countries)   5.00
# 3    2003  European Union (28 countries)   5.03
# 4    2004  European Union (28 countries)   4.95
# ..    ...                            ...    ...
# 379  2007                        Finland   5.90
# 380  2008                        Finland   6.10
# 381  2009                        Finland   6.81
# 382  2010                        Finland   6.85
# 383  2011                        Finland   6.76
#
# [384 rows x 3 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Uso del metodo head

# %%
edu.head()

#La función usar_head toma un DataFrame y un número opcional n (por defecto 5) como argumentos.
#Utiliza el método head() del DataFrame para devolver las primeras n filas.
# Out:
#    TIME                            GEO  Value
# 0  2000  European Union (28 countries)    NaN
# 1  2001  European Union (28 countries)    NaN
# 2  2002  European Union (28 countries)   5.00
# 3  2003  European Union (28 countries)   5.03
# 4  2004  European Union (28 countries)   4.95

# %% [markdown]
# ## Uso del metodo tail

# %%
edu.tail()
#La función usar_tail toma un DataFrame y un número opcional n (por defecto 5) como argumentos.
#Utiliza el método tail() del DataFrame para devolver las últimas n filas.
# Out:
#      TIME      GEO  Value
# 379  2007  Finland   5.90
# 380  2008  Finland   6.10
# 381  2009  Finland   6.81
# 382  2010  Finland   6.85
# 383  2011  Finland   6.76

# %% [markdown]
# ## Uso del metodo describe

# %%
edu.describe()
# Out:
#               TIME       Value
# count   384.000000  361.000000
# mean   2005.500000    5.203989
# std       3.456556    1.021694
# min    2000.000000    2.880000
# 25%    2002.750000    4.620000
# 50%    2005.500000    5.060000
# 75%    2008.250000    5.660000
# max    2011.000000    8.810000

# %% [markdown]
# ## Traer los valores

# %%
edu['Value']
# Out:
# 0       NaN
# 1       NaN
# 2      5.00
# 3      5.03
# 4      4.95
#        ...
# 379    5.90
# 380    6.10
# 381    6.81
# 382    6.85
# 383    6.76
# Name: Value, Length: 384, dtype: float64

# %% [markdown]
# ## Mostrar Rango del 10 al 14

# %%
edu[10:14]
# Out:
#     TIME                            GEO  Value
# 10  2010  European Union (28 countries)   5.41
# 11  2011  European Union (28 countries)   5.25
# 12  2000  European Union (27 countries)   4.91
# 13  2001  European Union (27 countries)   4.99

# %%
edu.loc[90:94, ['TIME','GEO']]
# Out:
#     TIME      GEO
# 90  2006  Belgium
# 91  2007  Belgium
# 92  2008  Belgium
# 93  2009  Belgium
# 94  2010  Belgium

# %% [markdown]
# ## Filtrando los Datos

# %%
edu[edu['Value'] > 6.5].tail()
# Out:
#      TIME      GEO  Value
# 286  2010    Malta   6.74
# 287  2011    Malta   7.96
# 381  2009  Finland   6.81
# 382  2010  Finland   6.85
# 383  2011  Finland   6.76

# %%
edu[edu["Value"].isnull()].head()
# Out:
#     TIME                            GEO  Value
# 0   2000  European Union (28 countries)    NaN
# 1   2001  European Union (28 countries)    NaN
# 36  2000       Euro area (18 countries)    NaN
# 37  2001       Euro area (18 countries)    NaN
# 48  2000       Euro area (17 countries)    NaN

# %% [markdown]
# ## Manipulando la Data

# %%
edu.max(axis = 0)
# Out:
# TIME      2011
# GEO      Spain
# Value     8.81
# dtype: object

# %% [markdown]
# ## Funcion pandas

# %%
print ("Pandas max function:", edu['Value']. max ())
print ("Python max function:", max(edu['Value']))
# Out:
# Pandas max function: 8.81
# Python max function: nan

# %% [markdown]
# ## Aplicando aritmética binaria

# %%
s = edu["Value" ]/100

s.head()
# Out:
# 0       NaN
# 1       NaN
# 2    0.0500
# 3    0.0503
# 4    0.0495
# Name: Value, dtype: float64

# %% [markdown]
# ##Metodo Aplicar

# %%
s = edu["Value"].apply (np.sqrt)

s.head()
# Out:
# 0         NaN
# 1         NaN
# 2    2.236068
# 3    2.242766
# 4    2.224860
# Name: Value, dtype: float64

# %% [markdown]
# ## Especificando parametros

# %%
s = edu["Value"].apply ( lambda d: d**2)

s.head()
# Out:
# 0        NaN
# 1        NaN
# 2    25.0000
# 3    25.3009
# 4    24.5025
# Name: Value, dtype: float64

# %% [markdown]
# ## Denominar variable ValueNorm

# %%
edu['ValueNorm'] = edu['Value']/edu['Value']. max ()

edu.tail()
# Out:
#      TIME      GEO  Value  ValueNorm
# 379  2007  Finland   5.90   0.669694
# 380  2008  Finland   6.10   0.692395
# 381  2009  Finland   6.81   0.772985
# 382  2010  Finland   6.85   0.777526
# 383  2011  Finland   6.76   0.767310

# %% [markdown]
# ## Elimina de la tabla los campos que tengan 1 en el valueNorm

# %%
edu.drop('ValueNorm', axis = 1, inplace = True)

edu.head()
# Out:
#    TIME                            GEO  Value
# 0  2000  European Union (28 countries)    NaN
# 1  2001  European Union (28 countries)    NaN
# 2  2002  European Union (28 countries)   5.00
# 3  2003  European Union (28 countries)   5.03
# 4  2004  European Union (28 countries)   4.95

# %% [markdown]
# ## concatena lo de el arreglo edu y el nuevo que se crea

# %%
edu = pd.concat([edu, pd.DataFrame({"TIME": [2000],"Value": [5.00],"GEO": ["a"]})], ignore_index=True)
edu.tail()
# Out:
#      TIME      GEO  Value
# 379  2007  Finland   5.90
# 380  2008  Finland   6.10
# 381  2009  Finland   6.81
# 382  2010  Finland   6.85
# 383  2000        a   5.00

# %% [markdown]
# ## elimina el campo que tenga el indice mayor valor

# %%
edu.drop(max(edu.index), axis = 0, inplace = True)

edu.tail()
# Out:
#      TIME      GEO  Value
# 378  2006  Finland   6.18
# 379  2007  Finland   5.90
# 380  2008  Finland   6.10
# 381  2009  Finland   6.81
# 382  2010  Finland   6.85

# %% [markdown]
# ## Elimina todas las filas de un DataFrame y muetsra las primeras filas

# %%
axis = edu["Value"].isnull()
eduDrop = edu.drop(edu[axis].index)
eduDrop.head()
# Out:
#    TIME                            GEO  Value
# 2  2002  European Union (28 countries)   5.00
# 3  2003  European Union (28 countries)   5.03
# 4  2004  European Union (28 countries)   4.95
# 5  2005  European Union (28 countries)   4.92
# 6  2006  European Union (28 countries)   4.91

# %% [markdown]
# ## Contiene solo las filas no nulas

# %%
eduDrop = edu.dropna(how = 'any', subset = ["Value"])

eduDrop. head()
# Out:
#    TIME                            GEO  Value
# 2  2002  European Union (28 countries)   5.00
# 3  2003  European Union (28 countries)   5.03
# 4  2004  European Union (28 countries)   4.95
# 5  2005  European Union (28 countries)   4.92
# 6  2006  European Union (28 countries)   4.91

# %% [markdown]
# ## Rellena los valores nulos llamado eduFilled

# %%
eduFilled = edu. fillna(value = {"Value": 0})

eduFilled. head()
# Out:
#    TIME                            GEO  Value
# 0  2000  European Union (28 countries)   0.00
# 1  2001  European Union (28 countries)   0.00
# 2  2002  European Union (28 countries)   5.00
# 3  2003  European Union (28 countries)   5.03
# 4  2004  European Union (28 countries)   4.95

# %% [markdown]
# ## Ordena las filas y muestra las primeras filas

# %%
edu.sort_values(by = 'Value', ascending = False ,
inplace = True)
edu.head()
# Out:
#      TIME      GEO  Value
# 130  2010  Denmark   8.81
# 131  2011  Denmark   8.75
# 129  2009  Denmark   8.74
# 121  2001  Denmark   8.44
# 122  2002  Denmark   8.44

# %% [markdown]
# ## Ordena de  ascendente y luego muestra las primeras filas

# %%
edu.sort_index( axis = 0, ascending = True , inplace = True)

edu.head()
# Out:
#    TIME                            GEO  Value
# 0  2000  European Union (28 countries)    NaN
# 1  2001  European Union (28 countries)    NaN
# 2  2002  European Union (28 countries)   5.00
# 3  2003  European Union (28 countries)   5.03
# 4  2004  European Union (28 countries)   4.95

# %% [markdown]
# ## Agrupa los datos y que contiene los prmedios

# %%
group = edu[["GEO", "Value"]].groupby('GEO').mean()

group.head()
# Out:
#                    Value
# GEO
# Austria         5.618333
# Belgium         6.189091
# Bulgaria        4.093333
# Cyprus          7.023333
# Czech Republic  4.168333

# %% [markdown]
# ## Crea una tabla pivote mostrando los valores de la columna

# %%
filtered_data = edu[edu["TIME"] > 2005]

pivedu = pd. pivot_table( filtered_data , values = 'Value',

index = ['GEO'] ,
columns = ['TIME'])

pivedu.head()
# Out:
# TIME            2006  2007  2008  2009  2010  2011
# GEO
# Austria         5.40  5.33  5.47  5.98  5.91  5.80
# Belgium         5.98  6.00  6.43  6.57  6.58  6.55
# Bulgaria        4.04  3.88  4.44  4.58  4.10  3.82
# Cyprus          7.02  6.95  7.45  7.98  7.92  7.87
# Czech Republic  4.42  4.05  3.92  4.36  4.25  4.51

# %% [markdown]
# ## Extrae datos especificos

# %%
pivedu.loc[[ 'Spain','Portugal'], [2006,2011]]
# Out:
# TIME      2006  2011
# GEO
# Spain     4.26  4.82
# Portugal  5.07  5.27

# %% [markdown]
# ## Elimina filas, renombra la etiqueta, calcula el rango de valores

# %%
pivedu = pivedu.drop([
'Euro area (13 countries)',
'Euro area (15 countries)',
'Euro area (17 countries)',
'Euro area (18 countries)',
'European Union (25 countries)',
'European Union (27 countries)',
'European Union (28 countries)'
] ,
axis = 0)

pivedu = pivedu.rename(index = {'Germany ( until 1990 former territory of the FRG)': 'Germany'})
pivedu = pivedu.dropna()
pivedu.rank( ascending = False , method = 'first').head()
# Out:
# TIME            2006  2007  2008  2009  2010  2011
# GEO
# Austria          9.0   6.0  10.0   6.0   7.0   7.0
# Belgium          4.0   4.0   3.0   3.0   4.0   4.0
# Bulgaria        20.0  20.0  19.0  19.0  21.0  21.0
# Cyprus           2.0   2.0   2.0   2.0   2.0   3.0
# Czech Republic  18.0  19.0  20.0  20.0  19.0  18.0

# %% [markdown]
# ## Suma de los valores de cada fila, ordena estos rangos en orden ascendente y muestra las primeras filas

# %%
totalSum = pivedu. sum(axis = 1)

totalSum. rank( ascending = False , method = 'dense').sort_values(). head()
# Out:
# GEO
# Denmark    1.0
# Cyprus     2.0
# Malta      3.0
# Belgium    4.0
# Ireland    5.0
# dtype: float64

# %% [markdown]
# ## Calcula las sumas totales de los valores de cada país y crea un grafo

# %%
totalSum = pivedu. sum(axis = 1).sort_values(ascending = False)
totalSum. plot(kind = 'bar', style = 'b', alpha = 0.4,
title = "Total Values for Country")
# Out:
# <Axes: title={'center': 'Total Values for Country'}, xlabel='GEO'>

# %% [markdown]
# ## Crea un gráfico de barras horizontales apiladas usando colores personalizados para las barras

# %%
my_colors = ['b', 'r', 'g', 'y', 'm', 'c']
ax = pivedu. plot(kind = 'barh',
stacked = True ,
color = my_colors)

ax.legend(loc = 'center left', bbox_to_anchor = (1, .5))
